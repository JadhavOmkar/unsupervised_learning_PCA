# %% [markdown]
# ![title](https://raw.githubusercontent.com/JadhavOmkar/unsupervised_learning_PCA/master/intro.jpg)

# %% [markdown]
# # Inside the Notebook:
# #####        1. Import  libraries
# #####        2. Loading helper functions
# #####         3. Reading data and quick overiew
# #####         4. Target variables distribution
# #####         5. Independent variables distribution
# #####         6. Data preparation
# #####         7. Training models
# #####         8. Applying Principal Component Analysis
# #####         9. Summarizig models result

# %% [markdown]
# ## 1. Importing libraries

# %%
import pandas as pd                                                         ## for dataframe handling
import numpy as np                                                          ## array handling
from numpy import set_printoptions
import matplotlib.pyplot as plt                                             ## plotting
# %matplotlib inline
import seaborn as sns                                                       ## plotting
from statsmodels.stats.outliers_influence import variance_inflation_factor  ## VIF calculation
from statsmodels.regression.linear_model import OLS as ols                  ## VIF calculation
from sklearn.metrics import accuracy_score                                  ## model evaluation parameters
from sklearn.metrics import precision_score, recall_score, confusion_matrix,classification_report
                                                                            ## model evaluation parameters
from sklearn.metrics import f1_score, roc_auc_score, roc_curve,make_scorer  ## model evaluation parameters
from sklearn.model_selection import train_test_split,cross_val_score        ## Train Test split
from sklearn.svm import SVC                                                 ## SVM
from sklearn.model_selection import GridSearchCV                            ## Grid Search for hyperparameter tunning
from sklearn.decomposition import PCA                                       ## Principal Component Analysis object

# %% [markdown]
# ## 2. Loading helper functions

# %%
def generate_model_report(y_actual, y_predicted):
    """
    Calculate model evaluation parameters with input as actual Y column and predicted Y column
    """
    from sklearn.metrics import accuracy_score ## accuracy calculations
    from sklearn.metrics import precision_score, recall_score, confusion_matrix ## model evaluation parameters
    from sklearn.metrics import f1_score, roc_auc_score, roc_curve ##some more model evaluation parameters
    print("Accuracy = " , accuracy_score(y_actual, y_predicted))
    print("Precision = " ,precision_score(y_actual, y_predicted))
    print("Recall = " ,recall_score(y_actual, y_predicted))
    print("F1 Score = " ,f1_score(y_actual, y_predicted))
    pass

# %%
def quick_report(df):

  """ 
  This function will give a quick overview about dataset shape, dtypes, column names and NULL value count
  
  """
  print('Data Types:')
  print(df.dtypes)
  print("----------------------------------------------------------------------")  
  print('Rows and Columns:')
  print(df.shape)
  print("----------------------------------------------------------------------")  
  print('Column Names:')
  print(df.columns)
  print("----------------------------------------------------------------------")  
  print('Number of Null Values:',df.isnull().sum().sum())
  #print(df.isnull().sum().sum())
  if df.isnull().sum().sum()>0:
    print("----------------------------------------------------------------------")  
    print('Null Values across columns:')
    print(df.apply(lambda x: sum(x.isnull())))

# %%
def corrank(X):
    """
    This function calculates Correlated pairs within the dataframe 
    """
    import itertools
    df = pd.DataFrame([[(i,j),X.corr().loc[i,j]] for i,j in list(itertools.combinations(X.corr(), 2))],columns=['pairs','corr'])    
    finaldf=df.sort_values(by='corr',ascending=False)
    return finaldf

# %%
def scale_data(X):
    """
    This function will scale the data using StandardScaler function from Sklearn
    """
    from sklearn.preprocessing import StandardScaler
    scaler = StandardScaler()
    Y = scaler.fit_transform(X)
    Y=pd.DataFrame(Y,columns=[X.columns])
    return Y

# %%
def vif_cal(input_data):
    
    """
    This funtion calculates VIF value from each variables within the dataframe
    """
    #x_vars=input_data.drop([dependent_col], axis=1)
    x_vars=input_data
    xvar_names=x_vars.columns
    for i in range(0,xvar_names.shape[0]):
        y=x_vars[xvar_names[i]]
        x=x_vars[xvar_names.drop(xvar_names[i])]
        rsq=ols(endog=y, exog=x, data=x_vars).fit().rsquared
        vif=round(1/(1-rsq),2)
        print (xvar_names[i], " VIF = " , vif)

# %%
def f_importances(coef, names):
    
    """
    This function will plot feature names and their feature importance score
    """
    imp = coef
    imp,names = zip(*sorted(zip(imp,names)))
    plt.barh(range(len(names)), imp, align='center')
    plt.yticks(range(len(names)), names)
    plt.show()

# %% [markdown]
# ## 3. Reading data anda quick overview

# %%
##importing dataset
data=pd.read_csv('vehicle.csv')

# %%
data.head()
# Out:
#    compactness  circularity  distance_circularity  radius_ratio  \
# 0           95         48.0                  83.0         178.0
# 1           91         41.0                  84.0         141.0
# 2          104         50.0                 106.0         209.0
# 3           93         41.0                  82.0         159.0
# 4           85         44.0                  70.0         205.0
#
#    pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 0                  72.0                       10          162.0
# 1                  57.0                        9          149.0
# 2                  66.0                       10          207.0
# 3                  63.0                        9          144.0
# 4                 103.0                       52          149.0
#
#    elongatedness  pr.axis_rectangularity  max.length_rectangularity  \
# 0           42.0                    20.0                        159
# ...

# %%
quick_report(data)
# Out:
# Data Types:
# compactness                      int64
# circularity                    float64
# distance_circularity           float64
# radius_ratio                   float64
# pr.axis_aspect_ratio           float64
# max.length_aspect_ratio          int64
# scatter_ratio                  float64
# elongatedness                  float64
# pr.axis_rectangularity         float64
# max.length_rectangularity        int64
# scaled_variance                float64
# scaled_variance.1              float64
# scaled_radius_of_gyration      float64
# scaled_radius_of_gyration.1    float64
# skewness_about                 float64
# skewness_about.1               float64
# skewness_about.2               float64
# hollows_ratio                    int64
# class                           object
# dtype: object
# ----------------------------------------------------------------------
# Rows and Columns:
# (846, 19)
# ----------------------------------------------------------------------
# ...

# %%
data.describe().transpose()
# Out:
#                              count        mean         std    min     25%  \
# compactness                  846.0   93.678487    8.234474   73.0   87.00
# circularity                  846.0   44.823877    6.134272   33.0   40.00
# distance_circularity         846.0   82.100473   15.741569   40.0   70.00
# radius_ratio                 846.0  168.874704   33.401356  104.0  141.00
# pr.axis_aspect_ratio         846.0   61.677305    7.882188   47.0   57.00
# max.length_aspect_ratio      846.0    8.567376    4.601217    2.0    7.00
# scatter_ratio                846.0  168.887707   33.197710  112.0  147.00
# elongatedness                846.0   40.936170    7.811882   26.0   33.00
# pr.axis_rectangularity       846.0   20.580378    2.588558   17.0   19.00
# max.length_rectangularity    846.0  147.998818   14.515652  118.0  137.00
# scaled_variance              846.0  188.596927   31.360427  130.0  167.00
# scaled_variance.1            846.0  439.314421  176.496341  184.0  318.25
# ...

# %% [markdown]
# ## 4. Target variable distribution

# %%
data['class'].value_counts(normalize=True)
# Out:
# car    0.507092
# bus    0.257683
# van    0.235225
# Name: class, dtype: float64

# %%
data['class'].unique()
# Out:
# array(['van', 'car', 'bus'], dtype=object)

# %%
target=data.groupby('class')
target.max()
# Out:
#        compactness  circularity  distance_circularity  radius_ratio  \
# class
# bus            114         58.0                 109.0         252.0
# car            119         59.0                 112.0         234.0
# van            100         50.0                  92.0         333.0
#
#        pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# class
# bus                   126.0                       52          265.0
# car                    74.0                       13          227.0
# van                   138.0                       55          163.0
#
#        elongatedness  pr.axis_rectangularity  max.length_rectangularity  \
# class
# bus             47.0                    29.0                        175
# car             61.0                    25.0                        188
# van             58.0                    20.0                        170
#
#        scaled_variance  scaled_variance.1  scaled_radius_of_gyration  \
# class
# ...

# %% [markdown]
# ## 5. Independent variables distributions

# %% [markdown]
#  ##### 5.1 DIstribution plots

# %%
## Boxplot for all predictors
plt.rcParams.update({'figure.max_open_warning': 0})
cols = [col for col in data.columns if col not in ['class']]
for col in cols:
    plt.figure()
    plt.xlabel(col)
    data[col].plot.kde()

# %% [markdown]
# ##### 5.2 Boxplots for outlier detection

# %%
## Boxplot for all predictors
plt.rcParams.update({'figure.max_open_warning': 0})
for column in data:
    plt.figure()
    data.boxplot([column])

# %% [markdown]
# ##### 5.3 Skewed values for predictors

# %%
#df2=df.drop('class',axis=1)
for col in data.columns:
  #df = data[col]
  print("Skewwed value for {} is {}".format(col,data[col].skew()))
# Out:
# Skewwed value for compactness is 0.38127063263996497
# Skewwed value for circularity is 0.2649279874901165
# Skewwed value for distance_circularity is 0.10871801180935975
# Skewwed value for radius_ratio is 0.3975716412698015
# Skewwed value for pr.axis_aspect_ratio is 3.8353916077858434
# Skewwed value for max.length_aspect_ratio is 6.7783936191089476
# Skewwed value for scatter_ratio is 0.6087097328672928
# Skewwed value for elongatedness is 0.046951051315584164
# Skewwed value for pr.axis_rectangularity is 0.7744056757899445
# Skewwed value for max.length_rectangularity is 0.2563591641353724
# Skewwed value for scaled_variance is 0.6555976294220067
# Skewwed value for scaled_variance.1 is 0.8453454281630146
# Skewwed value for scaled_radius_of_gyration is 0.27990964799345835
# Skewwed value for scaled_radius_of_gyration.1 is 2.0899787533912066
# Skewwed value for skewness_about is 0.7808132397211246
# Skewwed value for skewness_about.1 is 0.6890143067342678
# ...

# %% [markdown]
# #### Highly skewed variables are pr.axis_aspect_ratio,max.length_aspect_ratio,scaled_radius_of_gyration.1

# %%
radiu_gy=data[['pr.axis_aspect_ratio','scaled_radius_of_gyration.1','max.length_aspect_ratio','class']]

# %%
sns.pairplot(radiu_gy,hue='class')

# %% [markdown]
# ##### 5.4 Correlation plot

# %%
fig_dims = (18, 18)
fig, ax = plt.subplots(figsize=fig_dims)
corr=data.corr()
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))
sns.heatmap(corr,mask=mask,annot=True,square=True,ax=ax,cmap="YlGnBu")

# %% [markdown]
# ##### 5.5 Top 20 highest correlated pairs

# %%
correlation_df=corrank(data)
print("Top 20 highly correlated pairs within the dataframe")
correlation_df.head(20)
# Out:
# Top 20 highly correlated pairs within the dataframe
#                                                  pairs      corr
# 91                  (scatter_ratio, scaled_variance.1)  0.993012
# 88             (scatter_ratio, pr.axis_rectangularity)  0.989751
# 110        (pr.axis_rectangularity, scaled_variance.1)  0.988213
# 24            (circularity, max.length_rectangularity)  0.961318
# 90                    (scatter_ratio, scaled_variance)  0.948662
# 125               (scaled_variance, scaled_variance.1)  0.945678
# 109          (pr.axis_rectangularity, scaled_variance)  0.934227
# 27            (circularity, scaled_radius_of_gyration)  0.925816
# 36               (distance_circularity, scatter_ratio)  0.905076
# 38      (distance_circularity, pr.axis_rectangularity)  0.893025
# 152                  (skewness_about.2, hollows_ratio)  0.892581
# 41           (distance_circularity, scaled_variance.1)  0.886017
# 119  (max.length_rectangularity, scaled_radius_of_g...  0.866450
# ...

# %%
correlation_df[correlation_df['corr']>0.6].count()
# Out:
# pairs    44
# corr     44
# dtype: int64

# %% [markdown]
# 44 pairs among the data are highly correlated

# %% [markdown]
# ### **Observations on Independent variables**
#
# 1.   Pedictors such as pr.axis_aspect_ratio,max.length_aspect_ratio,scaled_radius_of_gyration.1 are having skewed distribution which is been indicated in the boxplot in point 5.2 and we might have to cap the outliers.
# 2. Most of the outliers values are for class bus and the proportion of observations for class bus is already low compared to car and van hence we cannot remove the outliers.
# 3.  14 among 18 indep variables have missing values.
# 4.   Distance_circularity,scatter_ratio,elongatedness,pr_axis_rectangularity,scaled_variance,scaled_variance 1,hollows_ratio have bi-modal distribution.
# 5.   44 pairs among the data are highly correlated
# 6. Carrying out VIF calculations would be key for the current dataframe.

# %% [markdown]
# ## 6. Data Preprocessing

# %% [markdown]
# ##### 6.1 Replacing levels under target column with numeric value such as 'van'==0, 'bus'==1, 'car'==2

# %%
data['class'].replace(['van','bus','car'], [0,1,2],inplace=True)

# %% [markdown]
# ##### 6.2 Replacing NA's with median

# %%
data.fillna(data.median(),inplace=True)

# %% [markdown]
# ##### 6.3 Caping outliers with 99th percentile

# %%
data[['pr.axis_aspect_ratio','scaled_radius_of_gyration.1','max.length_aspect_ratio']].describe()
# Out:
#        pr.axis_aspect_ratio  scaled_radius_of_gyration.1  \
# count            846.000000                   846.000000
# mean              61.677305                    72.443262
# std                7.882188                     7.468734
# min               47.000000                    59.000000
# 25%               57.000000                    67.000000
# 50%               61.000000                    71.500000
# 75%               65.000000                    75.000000
# max              138.000000                   135.000000
#
#        max.length_aspect_ratio
# count               846.000000
# mean                  8.567376
# std                   4.601217
# min                   2.000000
# 25%                   7.000000
# 50%                   8.000000
# 75%                  10.000000
# max                  55.000000

# %%
data[['pr.axis_aspect_ratio','scaled_radius_of_gyration.1','max.length_aspect_ratio']].quantile(0.99)
# Out:
# pr.axis_aspect_ratio           75.55
# scaled_radius_of_gyration.1    89.55
# max.length_aspect_ratio        23.65
# Name: 0.99, dtype: float64

# %%
data['pr.axis_aspect_ratio'] = np.clip(data['pr.axis_aspect_ratio'],a_min=data['pr.axis_aspect_ratio'].min(),a_max=75.55)
data['scaled_radius_of_gyration.1'] = np.clip(data['scaled_radius_of_gyration.1'],a_min=data['scaled_radius_of_gyration.1'].min(),a_max=89.55)
data['max.length_aspect_ratio'] = np.clip(data['max.length_aspect_ratio'],a_min=data['max.length_aspect_ratio'].min(),a_max=23.65)

# %%
data[['pr.axis_aspect_ratio','scaled_radius_of_gyration.1','max.length_aspect_ratio']].describe()
# Out:
#        pr.axis_aspect_ratio  scaled_radius_of_gyration.1  \
# count            846.000000                   846.000000
# mean              61.291903                    72.254078
# std                5.782573                     6.557656
# min               47.000000                    59.000000
# 25%               57.000000                    67.000000
# 50%               61.000000                    71.500000
# 75%               65.000000                    75.000000
# max               75.550000                    89.550000
#
#        max.length_aspect_ratio
# count               846.000000
# mean                  8.323700
# std                   2.725435
# min                   2.000000
# 25%                   7.000000
# 50%                   8.000000
# 75%                  10.000000
# max                  23.650000

# %% [markdown]
# ##### 6.4 Creating a copy of dataframe, applying scale_data function to standardise the variables & running VIF loop and considering final set of variables with vif less than or equal to 10

# %%
vif_data=data.copy()

# %%
vif_data.drop('class',axis=1,inplace=True)

# %%
vif_data=scale_data(vif_data)

# %% [markdown]
# Running VIF loop manually

# %%
## Loop 2 Revmoing scatter_ratio 
## Loop 3 Removing scaled_variance.1
## Loop 4 Removing Shimmer
## Loop 5 Removing Jitter%
## Loop 6 Removing Shimmer_dB
## Loop 7 Removing RAP
## Loop 8 Removing spread1
## Loop 9 Removing APQ5
## Loop 10 Removing PPQ
## Loop 11 Removing PPE
## Loop 12 Removing spread2
## Loop 13 Removing HNR
## Loop 14 Removing Jitter_abs
## Loop 15 Removing DDA
## Loop 16 Removing D2

vif_df=vif_data[vif_data.columns[~vif_data.columns.isin([['scatter_ratio'],
                                                         ['scaled_variance.1'],
                                                         ['circularity'],
                                                         ['scaled_variance'],
                                                         ['pr.axis_rectangularity'],
                                                         ['hollows_ratio'],
                                                         ['distance_circularity'],
                                                         ['radius_ratio']])]]
#vif_df=vif_data[cols]
vif_cal(vif_df)
# Out:
# ('compactness',)  VIF =  3.76
# ('pr.axis_aspect_ratio',)  VIF =  1.51
# ('max.length_aspect_ratio',)  VIF =  1.63
# ('elongatedness',)  VIF =  5.55
# ('max.length_rectangularity',)  VIF =  6.58
# ('scaled_radius_of_gyration',)  VIF =  6.64
# ('scaled_radius_of_gyration.1',)  VIF =  3.56
# ('skewness_about',)  VIF =  1.22
# ('skewness_about.1',)  VIF =  1.2
# ('skewness_about.2',)  VIF =  4.55

# %% [markdown]
# ##### 6.5 Creating final dataframe for trainning model

# %%
X=vif_data[['compactness','pr.axis_aspect_ratio','max.length_aspect_ratio','elongatedness','max.length_rectangularity',
            'scaled_radius_of_gyration','scaled_radius_of_gyration.1','skewness_about','skewness_about.1','skewness_about.2']]

# %%
X=pd.DataFrame(X)

# %%
y=data.pop('class')

# %%
print('Dataframe dimension for predictors is {} and for the target class is {}'.format(X.shape,y.shape))
# Out:
# Dataframe dimension for predictors is (846, 10) and for the target class is (846,)

# %% [markdown]
# Creating Train Test set

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %% [markdown]
# ## 7. Trainning model

# %% [markdown]
# ##### 7.1 Applying SVM classifier on the data

# %%
# defining parameter range 
param_grid = {'kernel':['linear','rbf'],
              'C': [0.1, 1, 10, 100, 1000],  
              'gamma': [0.1, 0.01, 0.001, 0.0001,1]}

# %%
grid_search_SVM = GridSearchCV(SVC(), param_grid, cv=3)
grid_fit_SVM=grid_search_SVM.fit(X_train, Y_train)

# %%
best_clf_SVM=grid_fit_SVM.best_estimator_

# %%
best_clf_SVM
# Out:
# SVC(C=10, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.1, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
grid_search_SVM.best_score_
# Out:
# 0.9628347775555898

# %%
#Y_pred = final_model.predict(X_test_scaled)

best_clf_SVM.fit(X_train, Y_train)

# Make predictions using the new model.
best_train_predictions = best_clf_SVM.predict(X_train)
best_test_predictions = best_clf_SVM.predict(X_test)

# %%
print("Training set score for SVM: %f" % best_clf_SVM.score(X_train , Y_train))
print("Testing  set score for SVM: %f" % best_clf_SVM.score(X_test , Y_test ))
# Out:
# Training set score for SVM: 0.993243
# Testing  set score for SVM: 0.976378

# %%
print(confusion_matrix(Y_test,best_test_predictions))
print("\n")
print(classification_report(Y_test,best_test_predictions))
# Out:
# [[ 50   2   1]
#  [  0  59   1]
#  [  2   0 139]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95        53
#            1       0.97      0.98      0.98        60
#            2       0.99      0.99      0.99       141
#
#     accuracy                           0.98       254
#    macro avg       0.97      0.97      0.97       254
# weighted avg       0.98      0.98      0.98       254

# %% [markdown]
# **With all 10 variables, we are getting an accuracy of 99% on train set and 98% on the test set. Technically this model will be effective in application but from business point of view it will be always great to get the same result with fewer number of predictors. Producing each variable will cost some revenue to the business. For example collecting 'elongatedness' for all the vehicles when the model is applied in real world would take some cost. In order to reduce the model cost of application to the business we can try to reduce the number of variables in the model.
# This can be achieved by applying 'Feature Selection Method' on current model. Meaning we will consider only those variables which adds value to the models accuracy.**

# %% [markdown]
# ##### 7.2 Applying  Feature Selection on the data

# %% [markdown]
# Creating a list of all features which will be used in plotting feature importance score

# %%
feature_names=['compactness','pr.axis_aspect_ratio','max.length_aspect_ratio','elongatedness','max.length_rectangularity',
            'scaled_radius_of_gyration','scaled_radius_of_gyration.1','skewness_about','skewness_about.1','skewness_about.2']

# %% [markdown]
# Applying Feature selection method using Extra Trees Classifier and plotting feature importance

# %%
# Feature Importance
from sklearn import metrics
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
model.fit(X,y)
# display the relative importance of each attribute
print(model.feature_importances_)
# Out:
# [0.0829505  0.09102488 0.14139712 0.20667926 0.11110482 0.07577751
#  0.11671013 0.04227989 0.05404229 0.07803361]

# %%
f_importances(model.feature_importances_,feature_names)

# %% [markdown]
# **Creating a dataframe in a manner that each column is placed in order of its importance score**

# %%
# Creating a subset of dataframe with top 5 important variables according to the feature importance plot
X_fs=X[['elongatedness','max.length_aspect_ratio','scaled_radius_of_gyration.1'
        ,'max.length_rectangularity','pr.axis_aspect_ratio','compactness','skewness_about.2','scaled_radius_of_gyration'
        ,'skewness_about.1','skewness_about']]

# %% [markdown]
# **Creating a WHILE LOOP which will first create a 'X' dataframe initial with only one variable .i.e elongatedness and then after creating X_train and Y_train it will perform an grid search to find optimal parameters for the SVM model and apply the best score model on the X-train and Y-train will print score on train set and test set. Initial the loop will run for only one predictor which is 'elongatedness' then when n=2, the loop will run for two predictors which are 'elongatedness' & 'max.length_aspect_ratio' and so on till n=10.**
# **Finally we will compare the result for each loop and consider the model with optimal number of predictors which will be efficient and cost effective**

# %%
n = 1
while n < 11:
    subset=X_fs.iloc[:,0:n]
    X_train,X_test,Y_train,Y_test = train_test_split(subset, y, test_size=0.3, random_state=0)
    grid_search_SVM_fs = GridSearchCV(SVC(), param_grid, cv=3)
    grid_fit_SVM_fs=grid_search_SVM_fs.fit(X_train, Y_train)
    best_clf_SVM_fs=grid_fit_SVM_fs.best_estimator_
    grid_fit_SVM_fs.best_score_
    best_clf_SVM_fs.fit(X_train, Y_train)
    print('\033[1m Following score for dataframe with following predictor/predictors \033[0;0m',X_train.columns)
    print("\n")
    print("Training set score for SVM: %f" % best_clf_SVM_fs.score(X_train , Y_train))
    print("Testing  set score for SVM: %f" % best_clf_SVM_fs.score(X_test , Y_test ))
    print("\n")
    n=n+1
# Out:
#  Following score for dataframe with following predictor/predictors  MultiIndex([('elongatedness',)],
#            )
#
#
# Training set score for SVM: 0.677365
# Testing  set score for SVM: 0.696850
#
#
#  Following score for dataframe with following predictor/predictors  MultiIndex([(          'elongatedness',),
#             ('max.length_aspect_ratio',)],
#            )
#
#
# Training set score for SVM: 0.853041
# Testing  set score for SVM: 0.846457
#
#
#  Following score for dataframe with following predictor/predictors  MultiIndex([(              'elongatedness',),
#             (    'max.length_aspect_ratio',),
#             ('scaled_radius_of_gyration.1',)],
#            )
#
#
# Training set score for SVM: 0.866554
# Testing  set score for SVM: 0.881890
#
#
#  Following score for dataframe with following predictor/predictors  MultiIndex([(              'elongatedness',),
#             (    'max.length_aspect_ratio',),
#             ('scaled_radius_of_gyration.1',),
# ...

# %% [markdown]
# **From the output of the above while loop result, model score for dataframe with 5  predictors ('elongatedness', 'max.length_aspect_ratio', 'scaled_radius_of_gyration.1','max.length_rectangularity','pr.axis_aspect_ratio') is the optimum because the previous model score with initial 4 predictor had test set score of approx 93% and adding pr.axis_aspect_ratio' to the dataframe took the test score to 96% and when 6th predictor 'compactness' was added to the dataframe, the test set score reamined same. We can go ahead and create a final model with 5 predictors.**

# %%
X_final=X[['elongatedness','max.length_aspect_ratio','scaled_radius_of_gyration.1'
        ,'max.length_rectangularity','pr.axis_aspect_ratio']]

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X_final, y, test_size=0.3, random_state=0)

# %%
grid_search_SVM_opt = GridSearchCV(SVC(), param_grid, cv=3)
grid_fit_SVM_opt=grid_search_SVM_opt.fit(X_train, Y_train)
best_clf_SVM_opt=grid_fit_SVM_opt.best_estimator_
# best score
grid_search_SVM_opt.best_score_
# Out:
# 0.9357876565998394

# %%
best_clf_SVM_opt.fit(X_train, Y_train)

# Make predictions using the new model.
best_train_predictions_opt = best_clf_SVM_opt.predict(X_train)
best_test_predictions_opt = best_clf_SVM_opt.predict(X_test)

print("Training set score for SVM: %f" % best_clf_SVM_opt.score(X_train , Y_train))
print("Testing  set score for SVM: %f" % best_clf_SVM_opt.score(X_test , Y_test ))
# Out:
# Training set score for SVM: 0.944257
# Testing  set score for SVM: 0.964567

# %%
print(confusion_matrix(Y_test,best_test_predictions_opt))
print("\n")
print(classification_report(Y_test,best_test_predictions_opt))
# Out:
# [[ 49   1   3]
#  [  0  60   0]
#  [  3   2 136]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93        53
#            1       0.95      1.00      0.98        60
#            2       0.98      0.96      0.97       141
#
#     accuracy                           0.96       254
#    macro avg       0.96      0.96      0.96       254
# weighted avg       0.96      0.96      0.96       254

# %% [markdown]
# ## 8. Applying Principal Component Analysis

# %%
## Creating new dataframe which is scaled
X_pca=vif_data

# %%
from sklearn.decomposition import PCA
pca = PCA()
pca.fit_transform(X_pca)
# Out:
# array([[ 4.78893260e-01, -5.92084324e-01,  1.41661613e+00, ...,
#         -1.78122680e-03, -2.69385118e-02,  2.26638395e-02],
#        [-1.56861435e+00, -3.45817266e-01, -5.93369962e-01, ...,
#         -2.51598832e-02,  1.15435568e-02, -1.07714450e-02],
#        [ 3.82992330e+00,  1.83908433e-01,  4.12066386e-01, ...,
#          7.16209839e-02,  1.53426458e-01,  3.87123244e-02],
#        ...,
#        [ 4.94764731e+00, -1.20736340e-01,  1.34747047e+00, ...,
#         -3.17885824e-02, -2.04958128e-02,  4.32770546e-03],
#        [-3.30197236e+00, -1.03319139e+00, -1.10996468e+00, ...,
#          1.54495792e-01,  6.79354117e-02,  1.86967798e-03],
#        [-4.87706982e+00,  4.23983959e-01, -9.76935450e-01, ...,
#          6.86793080e-02,  1.07018669e-01, -3.37448846e-03]])

# %%
explained_variance=pca.explained_variance_ratio_
explained_variance
# Out:
# array([5.30440318e-01, 1.81664014e-01, 6.85153550e-02, 6.53839365e-02,
#        5.01110480e-02, 4.04354562e-02, 2.21661095e-02, 1.22925052e-02,
#        9.16920695e-03, 5.55788625e-03, 3.60475399e-03, 3.38305575e-03,
#        2.39226601e-03, 1.83121022e-03, 1.21157598e-03, 1.11918988e-03,
#        5.57183854e-04, 1.64927945e-04])

# %%
List_of_explained_var=explained_variance.tolist()

# %%
print("Percentage of variance explained by each principal component :")
for x in List_of_explained_var:
    print(round((float(x))*100,2),"%")
# Out:
# Percentage of variance explained by each principal component :
# 53.04 %
# 18.17 %
# 6.85 %
# 6.54 %
# 5.01 %
# 4.04 %
# 2.22 %
# 1.23 %
# 0.92 %
# 0.56 %
# 0.36 %
# 0.34 %
# 0.24 %
# 0.18 %
# 0.12 %
# 0.11 %
# 0.06 %
# 0.02 %

# %%
with plt.style.context('dark_background'):
    plt.figure(figsize=(6, 4))

    plt.bar(range(18), explained_variance, alpha=0.5, align='center',
            label='individual explained variance')
    plt.ylabel('Explained variance ratio')
    plt.xlabel('Principal components')
    plt.legend(loc='best')
    plt.tight_layout()

# %% [markdown]
# **Thus we can see from the above plot and result from the formloop that first two components constitute almost 71% of the variance.Third, fourth, fifth, sixth and seventh components has 25% of the data spread. That totals up to 95% of the total variance explained. The rest all component has less than 5% of the variance.Hence we can drop the rest components.**
# ##### We will consider first 7 PC !!

# %%
pca=PCA(n_components=7)
X_new=pca.fit_transform(X_pca)
#X_new

# %%
explained_variance=pca.explained_variance_ratio_
explained_variance
# Out:
# array([0.53044032, 0.18166401, 0.06851536, 0.06538394, 0.05011105,
#        0.04043546, 0.02216611])

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.3, random_state=0)
X_train.shape
# Out:
# (592, 7)

# %%
# defining parameter range 
param_grid = {'kernel':['linear','rbf'],
              'C': [0.1, 1, 10, 100, 1000],  
              'gamma': [0.1, 0.01, 0.001, 0.0001,1]}

# %%
grid_search_SVM = GridSearchCV(SVC(), param_grid, cv=3)
grid_fit_SVM=grid_search_SVM.fit(X_train, y_train)

# %%
best_clf_SVM=grid_fit_SVM.best_estimator_

# %%
best_clf_SVM
# Out:
# SVC(C=10, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.1, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
grid_search_SVM.best_score_
# Out:
# 0.9222854603565263

# %%
#Y_pred = final_model.predict(X_test_scaled)

best_clf_SVM.fit(X_train, y_train)

# Make predictions using the new model.
best_train_predictions = best_clf_SVM.predict(X_train)
best_test_predictions = best_clf_SVM.predict(X_test)

# %%
print("Training set score for SVM using PCA: %f" % best_clf_SVM.score(X_train , y_train))
print("Testing  set score for SVM using PCA: %f" % best_clf_SVM.score(X_test , y_test ))
# Out:
# Training set score for SVM using PCA: 0.974662
# Testing  set score for SVM using PCA: 0.933071

# %%
print(confusion_matrix(y_test,best_test_predictions))
print("\n")
print(classification_report(y_test,best_test_predictions))
# Out:
# [[ 48   0   5]
#  [  0  58   2]
#  [  8   2 131]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88        53
#            1       0.97      0.97      0.97        60
#            2       0.95      0.93      0.94       141
#
#     accuracy                           0.93       254
#    macro avg       0.92      0.93      0.93       254
# weighted avg       0.93      0.93      0.93       254

# %% [markdown]
# ## 9. Summarizing Models Result

# %% [markdown]
# ##### Following results or score are based on the model for which best parameter were obtained through Grid Search Cross Validation
# 1. SVM with 10 independent variables
#     Trainset accuracy - 99%
#     Testset accuracy - 98%
# 2. SVM model with 5 independent variable (Applied feature selection on 10 variables)
#     Trainset accuracy - 94%
#     Testset accuracy - 96%
# 3. SVM model with 7 Principal components expalining 95% of the total variation
#     Trainset accuracy - 97%
#     Testset accuracy - 93%
#
# ##### From business point of view and also from the results it would be more logical to consider the second approach .i.e. SVM with 5 independent variables to be the most efficient and cost effective. These variables are having highest impact of the models decision making algorithm and would be quite easy to explain it to the business. On the other hand, the third approach of using Principal components had successfully reduced the dimnesion of the data from 18 predictors to 7 PC expalinning 95% of the variability. But at the same time we have lost interpretability.

# %% [markdown]
# ## End
